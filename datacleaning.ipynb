# %% [markdown]
# # data information
# Data:
# - goodreads books data: basic book metadata (NEVERMIND)
# - amazon books data : more detailed book data
# - amazon reviews: detailed text reviews for each book
# - (MAYBE)web scraping from reddit could be useful ?
#
# LINK TO DOWNLOAD THE ORIGINAL UNCLEAN CSVs: download both csvs
# - https://www.kaggle.com/datasets/mohamedbakhet/amazon-books-reviews
#
# LINK FOR THE CLEAN DATA DOWNLOAD:
# - https://drive.google.com/drive/folders/1ZGq4Bl4NIP6XLAPWCaVVO6tRYqr4A_lU?usp=sharing
#
# => output: books.csv, reviews.csv
#
# we then add the variables necessary to identify indie authors and other metrics that will be useful for our recommendation system.
#
# * is_indie: variable that indicates whether an author is indie or not,
# an author is defined as indie if :
#     - no publisher
#     - or very few books (< 3 books released) or  books released within the last 5 years starting from latest year in data set
#     - or very low visibility count on social media (reddit) / or very low reviews (less than 5 reviews ?, gotta check the median and avg review count per book/author)

# %%
#loading the data
import pandas as pd

books=pd.read_csv('books_data_amazon.csv')

# %%
#checking missing vals
print(books.columns)

print(books.isnull().sum())
books.head(5)
# Out:
# Index(['Title', 'description', 'authors', 'image', 'previewLink', 'publisher',
#        'publishedDate', 'infoLink', 'categories', 'ratingsCount'],
#       dtype='object')
# Title                 1
# description       68442
# authors           31413
# image             52075
# previewLink       23836
# publisher         75886
# publishedDate     25305
# infoLink          23836
# categories        41199
# ratingsCount     162652
# dtype: int64
#                                                Title  \
# 0                     Its Only Art If Its Well Hung!
# 1                           Dr. Seuss: American Icon
# 2              Wonderful Worship in Smaller Churches
# 3                      Whispers of the Wicked Saints
# 4  Nation Dance: Religion, Identity and Cultural ...
#
#                                          description              authors  \
# 0                                                NaN     ['Julie Strain']
# 1  Philip Nel takes a fascinating look into the k...       ['Philip Nel']
# 2  This resource includes twelve principles in un...     ['David R. Ray']
# 3  Julia Thomas finds her life spinning out of co...  ['Veronica Haddon']
# 4                                                NaN      ['Edward Long']
#
#                                                image  \
# 0  http://books.google.com/books/content?id=DykPA...
# 1  http://books.google.com/books/content?id=IjvHQ...
# 2  http://books.google.com/books/content?id=2tsDA...
# 3  http://books.google.com/books/content?id=aRSIg...
# 4                                                NaN
#
#                                          previewLink  publisher publishedDate  \
# 0  http://books.google.nl/books?id=DykPAAAACAAJ&d...        NaN          1996
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&p...  A&C Black    2005-01-01
# 2  http://books.google.nl/books?id=2tsDAAAACAAJ&d...        NaN          2000
# 3  http://books.google.nl/books?id=aRSIgJlq6JwC&d...  iUniverse       2005-02
# 4  http://books.google.nl/books?id=399SPgAACAAJ&d...        NaN    2003-03-01
#
#                                             infoLink  \
# 0  http://books.google.nl/books?id=DykPAAAACAAJ&d...
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&d...
# 2  http://books.google.nl/books?id=2tsDAAAACAAJ&d...
# 3  http://books.google.nl/books?id=aRSIgJlq6JwC&d...
# 4  http://books.google.nl/books?id=399SPgAACAAJ&d...
#
#                       categories  ratingsCount
# 0    ['Comics & Graphic Novels']           NaN
# 1  ['Biography & Autobiography']           NaN
# 2                   ['Religion']           NaN
# 3                    ['Fiction']           NaN
# 4                            NaN           NaN

# %% [markdown]
# ### cleaning the data

# %%
#missing values removed: titles, authors, 
#maybe keep: description and category if na (could use the reviews)
#dropping
import ast
books = books.dropna(subset=['Title', 'authors','description'])


#filling na
books['publisher'] = books['publisher'].fillna('self-published')
books['publishedDate'] = books['publishedDate'].fillna('Unknown')
books['image'] = books['image'].fillna('')
books['previewLink'] = books['previewLink'].fillna('')
books['infoLink'] = books['infoLink'].fillna('')
books['categories'] = books['categories'].fillna("['Uncategorized']")
books = books.drop('ratingsCount', axis=1)


print(books.shape)
# Out:
# (141755, 9)

# %%
#convert authors and categories to lists 
books['authors'] = books['authors'].apply(ast.literal_eval)
books['categories'] = books['categories'].apply(ast.literal_eval)

# %%
import re

#need to also normalize the authors 

def normalize_author_name(name):
    
    name = str(name).strip()
    name = name.replace('.', '')
    name = re.sub(r'\s+', ' ', name)
    name = re.sub(r'\b([A-Z])\s+(?=[A-Z]\s|\b[A-Z]$)', r'\1', name)
    name = name.title()
    
    return name

books['authors'] = books['authors'].apply(
    lambda author_list: [normalize_author_name(a) for a in author_list]
)

#since we got many authors adding a main author column
books['main_author'] = books['authors'].apply(lambda x: x[0])
#and main genre 
books['genre'] = books['categories'].apply(lambda x: x[0])

books.info
# Out:
# Top 20 authors after normalization:
# main_author
# William Shakespeare                     134
# Agatha Christie                         131
# Louis L'Amour                           115
# Edgar Rice Burroughs                     72
# Lonely Planet                            69
# Ann M Martin                             68
# Mark Twain                               66
# Carolyn Keene                            65
# Various                                  65
# Rl Stine                                 64
# Charles Dickens                          61
# Dk                                       59
# Cs Lewis                                 57
# Nora Roberts                             56
# Zane Grey                                54
# Isaac Asimov                             53
# John Steinbeck                           50
# Georgette Heyer                          50
# Rudyard Kipling                          50
# Library Of Congress Copyright Office     50
# Name: count, dtype: int64
# <bound method DataFrame.info of                                                     Title  \
# 1                                Dr. Seuss: American Icon
# 2                   Wonderful Worship in Smaller Churches
# 3                           Whispers of the Wicked Saints
# 5       The Church of Christ: A Biblical Ecclesiology ...
# 8                                Saint Hyacinth of Poland
# ...                                                   ...
# 212398               Autodesk Inventor 10 Essentials Plus
# 212399  The Orphan Of Ellis Island (Time Travel Advent...
# 212401                                              Mamaw
# 212402                                  The Autograph Man
# 212403  Student's Solutions Manual for Johnson/Mowry's...
#
#                                               description  \
# 1       Philip Nel takes a fascinating look into the k...
# 2       This resource includes twelve principles in un...
# 3       Julia Thomas finds her life spinning out of co...
# 5       In The Church of Christ: A Biblical Ecclesiolo...
# 8       The story for children 10 and up of St. Hyacin...
# ...                                                   ...
# 212398  Autodesk Inventor 2017 Essentials Plus provide...
# 212399  During a school trip to Ellis Island, Dominick...
# 212401  Give your Mamaw a useful, beautiful and though...
# 212402  Alex-Li Tandem sells autographs. His business ...
# 212403  Discover the many ways mathematics is relevant...
#
#                                   authors  \
# 1                            [Philip Nel]
# 2                           [David R Ray]
# 3                       [Veronica Haddon]
# 5                      [Everett Ferguson]
# 8                  [Mary Fabyan Windeatt]
# ...                                   ...
# 212398      [Daniel Banach, Travis Jones]
# 212399                  [Elvira Woodruff]
# 212401                [Wild Wild Cabbage]
# 212402                      [Zadie Smith]
# 212403  [David B Johnson, Thomas A Mowry]
#
#                                                     image  \
# 1       http://books.google.com/books/content?id=IjvHQ...
# 2       http://books.google.com/books/content?id=2tsDA...
# 3       http://books.google.com/books/content?id=aRSIg...
# 5       http://books.google.com/books/content?id=kVqRa...
# 8       http://books.google.com/books/content?id=lmLqA...
# ...                                                   ...
# 212398  http://books.google.com/books/content?id=zxHRC...
# 212399  http://books.google.com/books/content?id=J7M-N...
# 212401
# 212402  http://books.google.com/books/content?id=JM6YV...
# 212403  http://books.google.com/books/content?id=dehfP...
#
#                                               previewLink  \
# 1       http://books.google.nl/books?id=IjvHQsCn_pgC&p...
# 2       http://books.google.nl/books?id=2tsDAAAACAAJ&d...
# 3       http://books.google.nl/books?id=aRSIgJlq6JwC&d...
# 5       http://books.google.nl/books?id=kVqRaiPlx88C&p...
# 8       http://books.google.nl/books?id=lmLqAAAACAAJ&d...
# ...                                                   ...
# 212398  http://books.google.com/books?id=zxHRCwAAQBAJ&...
# 212399  http://books.google.com/books?id=J7M-NwAACAAJ&...
# 212401  http://books.google.com/books?id=zytVswEACAAJ&...
# 212402  http://books.google.com/books?id=JM6YVPx_clMC&...
# 212403  http://books.google.com/books?id=dehfPgAACAAJ&...
#
#                              publisher publishedDate  \
# 1                            A&C Black    2005-01-01
# 2                       self-published          2000
# 3                            iUniverse       2005-02
# 5           Wm. B. Eerdmans Publishing          1996
# 8                      Tan Books & Pub    2009-01-01
# ...                                ...           ...
# 212398                SDC Publications       2016-03
# 212399           Scholastic Paperbacks    2000-06-01
# 212401                  self-published    2018-01-17
# 212402                         Vintage    2003-08-12
# 212403  Brooks/Cole Publishing Company    1998-01-01
#
#                                                  infoLink  \
# 1       http://books.google.nl/books?id=IjvHQsCn_pgC&d...
# 2       http://books.google.nl/books?id=2tsDAAAACAAJ&d...
# 3       http://books.google.nl/books?id=aRSIgJlq6JwC&d...
# 5       http://books.google.nl/books?id=kVqRaiPlx88C&d...
# 8       http://books.google.nl/books?id=lmLqAAAACAAJ&d...
# ...                                                   ...
# 212398  https://play.google.com/store/books/details?id...
# 212399  http://books.google.com/books?id=J7M-NwAACAAJ&...
# 212401  http://books.google.com/books?id=zytVswEACAAJ&...
# 212402  https://play.google.com/store/books/details?id...
# 212403  http://books.google.com/books?id=dehfPgAACAAJ&...
#
#                          categories           main_author  \
# 1       [Biography & Autobiography]            Philip Nel
# 2                        [Religion]           David R Ray
# 3                         [Fiction]       Veronica Haddon
# 5                        [Religion]      Everett Ferguson
# 8       [Biography & Autobiography]  Mary Fabyan Windeatt
# ...                             ...                   ...
# 212398                  [Computers]         Daniel Banach
# 212399           [Juvenile Fiction]       Elvira Woodruff
# 212401              [Uncategorized]     Wild Wild Cabbage
# 212402                    [Fiction]           Zadie Smith
# 212403              [Uncategorized]       David B Johnson
#
#                             genre
# 1       Biography & Autobiography
# 2                        Religion
# 3                         Fiction
# 5                        Religion
# 8       Biography & Autobiography
# ...                           ...
# 212398                  Computers
# 212399           Juvenile Fiction
# 212401              Uncategorized
# 212402                    Fiction
# 212403              Uncategorized
#
# [141755 rows x 11 columns]>

# %% [markdown]
# ## cleaning up reviews

# %%
reviews=pd.read_csv('books_reviews_amazon.csv')

# %%
reviews = reviews[['Id', 'Title', 'review/score', 'review/text']]

# %%
reviews = reviews.rename(columns={
    'Id': 'ISBN',
    'review/score': 'rating',
    'review/text': 'review_text'
})

# %%
#keep only reviews for books  that are in our books dataset after cleaning
reviews = reviews.dropna(subset=['Title'])
reviews['review_text'] = reviews['review_text'].fillna('')
reviews = reviews[reviews['Title'].isin(books['Title'])]
reviews.to_csv('reviews_clean.csv', index=False)

# %%
print(f"Average reviews per book: {len(reviews) / len(reviews['Title'].unique()):.1f}")
print(f"Cleaned reviews: {len(reviews):,}")
# Out:
# Average reviews per book: 16.5
# Cleaned reviews: 2,339,915

# %%
reviews.head(5)
# Out:
#          ISBN                     Title  rating  \
# 1  0826414346  Dr. Seuss: American Icon     5.0
# 2  0826414346  Dr. Seuss: American Icon     5.0
# 3  0826414346  Dr. Seuss: American Icon     4.0
# 4  0826414346  Dr. Seuss: American Icon     4.0
# 5  0826414346  Dr. Seuss: American Icon     4.0
#
#                                          review_text
# 1  I don't care much for Dr. Seuss but after read...
# 2  If people become the books they read and if "t...
# 3  Theodore Seuss Geisel (1904-1991), aka &quot;D...
# 4  Philip Nel - Dr. Seuss: American IconThis is b...
# 5  "Dr. Seuss: American Icon" by Philip Nel is a ...

# %%
#adding avg rating and review counts to books
review_stats = reviews.groupby('Title').agg({
    'rating': ['count', 'mean']
}).reset_index()

review_stats.columns = ['Title', 'review_count', 'avg_rating']

books = books.merge(review_stats, on='Title', how='left')

books['review_count'] = books['review_count'].fillna(0).astype(int)
books['avg_rating'] = books['avg_rating'].fillna(0)

# %%
books.to_csv('books_clean.csv', index=False)
books.head(3)
# Out:
#                                    Title  \
# 0               Dr. Seuss: American Icon
# 1  Wonderful Worship in Smaller Churches
# 2          Whispers of the Wicked Saints
#
#                                          description            authors  \
# 0  Philip Nel takes a fascinating look into the k...       [Philip Nel]
# 1  This resource includes twelve principles in un...      [David R Ray]
# 2  Julia Thomas finds her life spinning out of co...  [Veronica Haddon]
#
#                                                image  \
# 0  http://books.google.com/books/content?id=IjvHQ...
# 1  http://books.google.com/books/content?id=2tsDA...
# 2  http://books.google.com/books/content?id=aRSIg...
#
#                                          previewLink       publisher  \
# 0  http://books.google.nl/books?id=IjvHQsCn_pgC&p...       A&C Black
# 1  http://books.google.nl/books?id=2tsDAAAACAAJ&d...  self-published
# 2  http://books.google.nl/books?id=aRSIgJlq6JwC&d...       iUniverse
#
#   publishedDate                                           infoLink  \
# 0    2005-01-01  http://books.google.nl/books?id=IjvHQsCn_pgC&d...
# 1          2000  http://books.google.nl/books?id=2tsDAAAACAAJ&d...
# 2       2005-02  http://books.google.nl/books?id=aRSIgJlq6JwC&d...
#
#                     categories      main_author                      genre  \
# 0  [Biography & Autobiography]       Philip Nel  Biography & Autobiography
# 1                   [Religion]      David R Ray                   Religion
# 2                    [Fiction]  Veronica Haddon                    Fiction
#
#    review_count  avg_rating
# 0             9    4.555556
# 1             4    5.000000
# 2            32    3.718750

# %%
books.shape
# Out:
# (141755, 13)

# %% [markdown]
# ## adding is indie flag
#
# author is indie if any of these criteria :
#
# - less than 3 books published
# OR
# - self published
# OR
# - less than 15 reviews

# %%
indie_author = books.groupby('main_author').agg({'Title': 'count','review_count': 'sum'}).reset_index()

indie_author.columns = ['main_author', 'total_books', 'total_reviews']

self_pub = books.groupby('main_author')['publisher'].apply(lambda x: 'self-published' in x.str.lower().values).reset_index(name='is_self_published')

indie_author = indie_author.merge(self_pub, on='main_author')

indie_author['is_indie'] = (
    (indie_author['is_self_published']) & (
    (indie_author['total_books'] < 3) |
    (indie_author['total_reviews'] < 20))
)

print(f"Indie authors: {indie_author['is_indie'].sum()} / {len(indie_author)}")
# Out:
# Indie authors: 13408 / 94318

# %%
books['is_indie'] = books['main_author'].map(indie_author.set_index('main_author')['is_indie']).fillna(False)
books.info
# Out:
# <bound method DataFrame.info of                                                     Title  \
# 0                                Dr. Seuss: American Icon
# 1                   Wonderful Worship in Smaller Churches
# 2                           Whispers of the Wicked Saints
# 3       The Church of Christ: A Biblical Ecclesiology ...
# 4                                Saint Hyacinth of Poland
# ...                                                   ...
# 141750               Autodesk Inventor 10 Essentials Plus
# 141751  The Orphan Of Ellis Island (Time Travel Advent...
# 141752                                              Mamaw
# 141753                                  The Autograph Man
# 141754  Student's Solutions Manual for Johnson/Mowry's...
#
#                                               description  \
# 0       Philip Nel takes a fascinating look into the k...
# 1       This resource includes twelve principles in un...
# 2       Julia Thomas finds her life spinning out of co...
# 3       In The Church of Christ: A Biblical Ecclesiolo...
# 4       The story for children 10 and up of St. Hyacin...
# ...                                                   ...
# 141750  Autodesk Inventor 2017 Essentials Plus provide...
# 141751  During a school trip to Ellis Island, Dominick...
# 141752  Give your Mamaw a useful, beautiful and though...
# 141753  Alex-Li Tandem sells autographs. His business ...
# 141754  Discover the many ways mathematics is relevant...
#
#                                   authors  \
# 0                            [Philip Nel]
# 1                           [David R Ray]
# 2                       [Veronica Haddon]
# 3                      [Everett Ferguson]
# 4                  [Mary Fabyan Windeatt]
# ...                                   ...
# 141750      [Daniel Banach, Travis Jones]
# 141751                  [Elvira Woodruff]
# 141752                [Wild Wild Cabbage]
# 141753                      [Zadie Smith]
# 141754  [David B Johnson, Thomas A Mowry]
#
#                                                     image  \
# 0       http://books.google.com/books/content?id=IjvHQ...
# 1       http://books.google.com/books/content?id=2tsDA...
# 2       http://books.google.com/books/content?id=aRSIg...
# 3       http://books.google.com/books/content?id=kVqRa...
# 4       http://books.google.com/books/content?id=lmLqA...
# ...                                                   ...
# 141750  http://books.google.com/books/content?id=zxHRC...
# 141751  http://books.google.com/books/content?id=J7M-N...
# 141752
# 141753  http://books.google.com/books/content?id=JM6YV...
# 141754  http://books.google.com/books/content?id=dehfP...
#
#                                               previewLink  \
# 0       http://books.google.nl/books?id=IjvHQsCn_pgC&p...
# 1       http://books.google.nl/books?id=2tsDAAAACAAJ&d...
# 2       http://books.google.nl/books?id=aRSIgJlq6JwC&d...
# 3       http://books.google.nl/books?id=kVqRaiPlx88C&p...
# 4       http://books.google.nl/books?id=lmLqAAAACAAJ&d...
# ...                                                   ...
# 141750  http://books.google.com/books?id=zxHRCwAAQBAJ&...
# 141751  http://books.google.com/books?id=J7M-NwAACAAJ&...
# 141752  http://books.google.com/books?id=zytVswEACAAJ&...
# 141753  http://books.google.com/books?id=JM6YVPx_clMC&...
# 141754  http://books.google.com/books?id=dehfPgAACAAJ&...
#
#                              publisher publishedDate  \
# 0                            A&C Black    2005-01-01
# 1                       self-published          2000
# 2                            iUniverse       2005-02
# 3           Wm. B. Eerdmans Publishing          1996
# 4                      Tan Books & Pub    2009-01-01
# ...                                ...           ...
# 141750                SDC Publications       2016-03
# 141751           Scholastic Paperbacks    2000-06-01
# 141752                  self-published    2018-01-17
# 141753                         Vintage    2003-08-12
# 141754  Brooks/Cole Publishing Company    1998-01-01
#
#                                                  infoLink  \
# 0       http://books.google.nl/books?id=IjvHQsCn_pgC&d...
# 1       http://books.google.nl/books?id=2tsDAAAACAAJ&d...
# 2       http://books.google.nl/books?id=aRSIgJlq6JwC&d...
# 3       http://books.google.nl/books?id=kVqRaiPlx88C&d...
# 4       http://books.google.nl/books?id=lmLqAAAACAAJ&d...
# ...                                                   ...
# 141750  https://play.google.com/store/books/details?id...
# 141751  http://books.google.com/books?id=J7M-NwAACAAJ&...
# 141752  http://books.google.com/books?id=zytVswEACAAJ&...
# 141753  https://play.google.com/store/books/details?id...
# 141754  http://books.google.com/books?id=dehfPgAACAAJ&...
#
#                          categories           main_author  \
# 0       [Biography & Autobiography]            Philip Nel
# 1                        [Religion]           David R Ray
# 2                         [Fiction]       Veronica Haddon
# 3                        [Religion]      Everett Ferguson
# 4       [Biography & Autobiography]  Mary Fabyan Windeatt
# ...                             ...                   ...
# 141750                  [Computers]         Daniel Banach
# 141751           [Juvenile Fiction]       Elvira Woodruff
# 141752              [Uncategorized]     Wild Wild Cabbage
# 141753                    [Fiction]           Zadie Smith
# 141754              [Uncategorized]       David B Johnson
#
#                             genre  review_count  avg_rating  is_indie
# 0       Biography & Autobiography             9    4.555556     False
# 1                        Religion             4    5.000000      True
# 2                         Fiction            32    3.718750     False
# 3                        Religion             4    4.500000     False
# 4       Biography & Autobiography             2    4.500000     False
# ...                           ...           ...         ...       ...
# 141750                  Computers             6    4.666667     False
# 141751           Juvenile Fiction            28    4.678571     False
# 141752              Uncategorized             3    4.666667      True
# 141753                    Fiction             4    2.500000     False
# 141754              Uncategorized             4    3.250000     False
#
# [141755 rows x 14 columns]>

# %%
books.to_csv('books_clean.csv', index=False)
indie_author.to_csv('authors_clean.csv', index=False)
